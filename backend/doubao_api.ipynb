# %%
# messages=[
#         {
#             "role": "user",
#             "content": [
#                 {
#                     "type": "image_url",
#                     "image_url": {
#                         "url": "https://ark-project.tos-cn-beijing.ivolces.com/images/view.jpeg"
#                     },
#                 },
#                 {"type": "text", "text": "这是哪里？"},
#             ],
#         }
#     ]

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

model = "doubao-seed-1-6-251015"
DOUBAO_API_KEY = os.getenv("DOUBAO_API_KEY")

client = OpenAI(
    base_url="https://ark.cn-beijing.volces.com/api/v3",
    api_key=DOUBAO_API_KEY,
)

def get_doubao_answer(
    query: str,
    system_prompt: str = None,
    stream: bool = True,
    thinking: bool = "disabled",
):
    messages = []
    if system_prompt is None:
        system_prompt = "你必须严格遵守我的要求。"

    system_message = {"role": "system", "content": system_prompt}
    user_message = {"role": "user", "content": query}
    messages.append(system_message)
    messages.append(user_message)

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        stream=stream,
        extra_body={"thinking": {"type": thinking}}
    )
    responses = []
    answer = ""
    for chunk in response:
        responses.append(chunk)
        if chunk.choices[0].delta.content:
            char = chunk.choices[0].delta.content
            answer += char
            print(char, end="", flush=True)
    return answer

question = "世界是模拟的吗？"
answer = get_doubao_answer(question)
# Out:
# 关于“世界是否是模拟的”这一问题，目前并没有科学上的确凿证据来证实或证伪。这一观点更多属于哲学思辨或科幻假说的范畴，例如哲学家尼克·博斯特罗姆提出的“模拟论证”认为，如果未来文明有能力且有意愿模拟大量的过去文明，那么我们生活在模拟世界中的概率可能很高。但这一论证本身基于多个假设（如未来文明的技术能力、模拟动机等），并非经过实证检验的科学理论。
#
# 从科学角度来看，我们对宇宙的认知建立在可观测、可验证的物理规律之上，目前所有的科学观察和实验都与我们生活在一个真实、客观的宇宙中这一框架相符。若要证明世界是模拟的，需要找到模拟系统中的“漏洞”或违背物理规律的异常现象，但截至目前，尚未发现此类证据。
#
# 这一问题更多地引发了人们对现实本质、意识与存在等哲学问题的思考，而科学的探索仍在不断拓展我们对宇宙的认知边界。如果你对相关哲学或科学话题感兴趣，可以进一步探讨具体的理论细节或科学发现哦。
